# %% [markdown]
# **ASSIGNMENT**

# %%
lis=['123','3024']
type(lis)

print(lis)
# Out:
# ['123', '3024']

# %%
 lis2=['engineering','324']
print(len(lis))
print(len(lis2))
lis3=lis+lis2
print(lis3)
print(len(lis3))
# Out:
# 2
# 2
# ['123', '3024', 'engineering', '324']
# 4

# %%
tuple=("tech","non tech","bvb")
print(tuple[1])
print(tuple[0])
print(tuple[-2])
tuple[1]
tuple[0]
tuple[-2]
# Out:
# non tech
# tech
# non tech
# 'non tech'

# %%
set1={"one","two","three"}
print(set1)
# Out:
# {'two', 'three', 'one'}

# %%
set1.add('zero')
print(set1)
# Out:
# {'two', 'three', 'one', 'zero'}

# %%
a=int(input("Enter a value:"))
print(a)
# Out:
# Enter a value:1
# 1

# %%
if((a%2)==0):
 print("number is even")
else:
 print("number is odd")
# Out:
# number is odd

# %%
a=25
b=16
print("sumprint squre root",a**0.5)
print("sumprint squre root",b**0.5)
print("sum od addition=",a+b)
print("sum of substraction",a-b)
print("sum of division",a/b)
print("sum of multiplication",a*b)
# Out:
# sumprint squre root 5.0
# sumprint squre root 4.0
# sum od addition= 41
# sum of substraction 9
# sum of division 1.5625
# sum of multiplication 400

# %%
Dict1={"stu name":"ani","usn no":"01fe22bec425"}
print(Dict1)
# Out:
# {'stu name': 'ani', 'usn no': '01fe22bec425'}
